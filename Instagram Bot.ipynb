# %%
import selenium
from selenium import webdriver
import time
import os
import requests
from bs4 import BeautifulSoup

# %%
driver = webdriver.Firefox()

def login(usr,pss):
    driver.get("https://www.instagram.com/")
    time.sleep(2)

    usr_ent = driver.find_element_by_xpath("/html/body/div[1]/section/main/article/div[2]/div[1]/div/form/div[2]/div/label/input")
    usr_ent.clear()
    usr_ent.send_keys(usr)
    time.sleep(2)

    pss_ent = driver.find_element_by_xpath("/html/body/div[1]/section/main/article/div[2]/div[1]/div/form/div[3]/div/label/input")
    pss_ent.clear()
    pss_ent.send_keys(pss)
    time.sleep(2)

    login = driver.find_element_by_xpath("/html/body/div[1]/section/main/article/div[2]/div[1]/div/form/div[4]")
    login.click()
    time.sleep(2)

login("username","password")
time.sleep(5)

# %%
notnow=driver.find_element_by_xpath("/html/body/div[1]/section/main/div/div/div/div/button")
notnow.click()

# %%
time.sleep(3)
notnow2=driver.find_element_by_xpath("/html/body/div[4]/div/div/div/div[3]/button[2]")
notnow2.click()

time.sleep(3)

# %%
profile=driver.find_element_by_xpath("/html/body/div[1]/section/main/section/div[3]/div[1]/div/div[2]/div[1]/a")
profile.click()
time.sleep(3)

# %%
gotoprof=driver.find_element_by_xpath("/html/body/div[1]/section/nav/div[2]/div/div/div[3]/div/div[5]/div[2]/div/div[2]/div[2]/a[1]/div")
time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-26-14b5bf0cc206> in <module>
# ----> 1 gotoprof=driver.find_element_by_xpath("/html/body/div[1]/section/nav/div[2]/div/div/div[3]/div/div[5]/div[2]/div/div[2]/div[2]/a[1]/div")
#       2 time.sleep(3)
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# ...

# %%
lenofpage=driver.execute_script("window.scrollTo(0,document.body.scrollHeight);var lenofpage=document.body.scrollHeight;return lenofpage;")
match=False
while(match==False):
    lastcount=lenofpage
    time.sleep(3)
    lenofpage=driver.execute_script("window.scrollTo(0,document.body.scrollHeight);var lenofpage=document.body.scrollHeight;return lenofpage;")
    if lastcount==lenofpage:
        match=True

# %%
page=driver.page_source
print(page)
# Out:
# <html class="js logged-in client-root js-focus-visible sDN5V" lang="en"><head>
#         <meta charset="utf-8">
#         <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
#         <title>@iamadityasingh11 • Instagram photos and videos</title>
#
#
#         <meta name="robots" content="noimageindex, noarchive">
#         <meta name="apple-mobile-web-app-status-bar-style" content="default">
#         <meta name="mobile-web-app-capable" content="yes">
#         <meta name="theme-color" content="#ffffff">
#         <meta id="viewport" name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1, viewport-fit=cover">
#         <link rel="manifest" href="/data/manifest.json">
#
#         <link rel="preload" href="/static/bundles/es6/ConsumerUICommons.css/ab9da11fae7d.css" as="style" type="text/css" crossorigin="anonymous">
# ...

# %%
soup=BeautifulSoup(page,'html.parser')
for i in soup('a',{'class':'-nal3'}):
    print(i.text)
# Out:
# 439 followers
# 516 following

# %%
posts=[]
links=driver.find_elements_by_tag_name('a')

# %%
for link in links:
    post=link.get_attribute('href')
    if '/p/' in post:
        posts.append(post)
# Out:
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# <ipython-input-58-6be813e30e77> in <module>
#       1 for link in links:
# ----> 2     post=link.get_attribute('href')
#       3     if '/p/' in post:
#       4         posts.append(post)
#       5
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\selenium\webdriver\remote\webelement.py in get_attribute(self, name)
#     139             attributeValue = self.parent.execute_script(
#     140                 "return (%s).apply(null, arguments);" % getAttribute_js,
# --> 141                 self, name)
#     142         else:
#     143             resp = self._execute(Command.GET_ELEMENT_ATTRIBUTE, {'name': name})
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute_script(self, script, *args)
#     634         return self.execute(command, {
# ...

# %%
print(posts)
# Out:
# ['https://www.instagram.com/p/B_SzuPnFRzKarqwvB8xQNpfHVG5F032vjS6UUs0/', 'https://www.instagram.com/p/BpmNrTEgcF9Tyq41eAscZBVBxKrtAuZItrKNgw0/', 'https://www.instagram.com/p/BlEp6zZBZZeTl6xQapElwcLNB4NDD6oquyreBM0/', 'https://www.instagram.com/p/BjNESXkAgCK1TRPA16AvOOSf15nBYMNDcTVU-U0/', 'https://www.instagram.com/p/Bekj_PUhiPWZ20OZp_QqRchV1pb5qz4daw8WDw0/', 'https://www.instagram.com/p/BekizEAhNrmm1xl4EYae-n3qmAKfv1-KONZUz00/', 'https://www.instagram.com/p/BcZrKqOh2SiFeqbIWU32LbFLFfnCOrdE6xMHh40/', 'https://www.instagram.com/p/BaWxgi0B3b7_5JFO8V_MatMBb2jmjg9LJz3OX80/', 'https://www.instagram.com/p/BVz41LVB4PG3oH2Ei3psdkTkvTsJl_lzn3ir9A0/', 'https://www.instagram.com/p/BPiOPxKDOaE1-t1v0NjnZUlev0HMaOOHsOPWtg0/', 'https://www.instagram.com/p/BPfh5bvju_dKNBBDfGcDi38HZG-M9DHQkCGkKo0/', 'https://www.instagram.com/p/BOXYziPDwRzkhSHoiYUMWIyxYOgnDQwWli69_o0/', 'https://www.instagram.com/p/BMIpixYh2Vxf6G3oW54VRSoAbzWIzcPlkXSgZc0/', 'https://www.instagram.com/p/BLRL1J4hbNHkPwziqMY1IwOhj3b5W9bu
# ...

# %%
print(len(posts))
# Out:
# 16

# %%
for i in range(len(posts)):
    driver.get(post[i])
    time.sleep(3)
